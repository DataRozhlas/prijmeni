# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
table = pd.read_csv('data.csv', index_col='JMÉNO')[:-1]

# %%
# počet unikátních jmen
for year in range(1916,2017):
    print(np.sum(table[str(year)].values!=0),end=",")
# Out:
# 86,132,141,223,269,366,435,537,605,650,730,782,888,953,1038,1081,1128,1177,1227,1267,1290,1334,1420,1440,1569,1585,1602,1687,1739,1669,1746,1684,1715,1734,1677,1696,1726,1670,1671,1641,1632,1637,1566,1548,1568,1575,1624,1680,1739,1742,1737,1669,1771,1792,1826,1839,1867,1803,1903,1896,1831,1778,1756,1744,1712,1654,1616,1559,1604,1640,1636,1701,1647,1786,1808,1988,2260,2263,2289,2300,2288,2343,2341,2190,2474,3500,3804,4026,4278,4647,5280,5578,6303,6434,6320,6159,6231,6219,6157,6198,5558,

# %%
# mediánový věk pro jméno
def get_median(name):
    subtable = table.loc[name].loc["1916":"2016"]
    year = 1916
    median_list = []
    for entry in subtable:
        for i in range(int(entry)):
            median_list.append(int(year))
        year+=1

    return median_list[round(len(median_list)/4)], median_list[round(len(median_list)/2)], median_list[3*round(len(median_list)/4)]

# %%
namecount = 0
name_medians = {}
for name, row in table.iterrows():
    if row["3000"] >= 1000:
        namecount += 1
        name_medians[name] = get_median(name)
print(namecount)
# Out:
# 416

# %%
medians_sorted = sorted(name_medians, key=lambda x: name_medians[x][1])

# nejstarší jména (podle medianu)
for name in medians_sorted[:120]:
    print("[" + str(2017-name_medians[name][2]) + ", " +str(2017-name_medians[name][0]) + "], //" + name.title(), end=" ")
    print(2017-name_medians[name][1])
# Out:
# [73, 86], //Aloisie 80
# [71, 83], //Alenka 77
# [70, 83], //Danuška 77
# [74, 84], //Gertruda 77
# [68, 84], //Josefa 76
# [66, 83], //Františka 75
# [67, 78], //Helga 75
# [69, 83], //Miluška 74
# [61, 79], //Adolf 73
# [65, 81], //Emilie 73
# [68, 83], //Jaruška 73
# [66, 80], //Lidmila 73
# [63, 81], //Bedřiška 72
# [64, 81], //Blažena 72
# [64, 81], //Božena 72
# [61, 76], //Krista 71
# [61, 80], //Růžena 71
# [65, 79], //Věnceslava 71
# [67, 73], //Ivanka 70
# [50, 81], //Anděla 69
# [60, 78], //Květoslava 69
# [55, 78], //Maria 69
# [59, 77], //Marie 69
# [60, 78], //Milada 69
# [62, 79], //Vlastimila 69
# [59, 78], //Zdenka 69
# [57, 80], //Zděnka 69
# [58, 76], //Alois 68
# [59, 76], //Alžbeta 68
# [48, 78], //Antonie 68
# [59, 77], //Leopold 68
# [60, 77], //Vlasta 68
# [55, 75], //Bohumila 67
# [60, 74], //Danuše 67
# [59, 78], //Drahoslava 67
# [53, 75], //Emanuel 67
# [54, 77], //Erich 67
# [54, 75], //Jindřiška 67
# [60, 80], //Květuše 67
# [59, 76], //Libuše 67
# [58, 75], //Ludmila 67
# [58, 75], //Mária 67
# [59, 75], //Miloslava 67
# [55, 74], //Bohumír 66
# [55, 74], //Bohuslava 66
# [58, 76], //Drahomíra 66
# [58, 74], //Emília 66
# [56, 75], //Jiřina 66
# [53, 74], //Marta 66
# [9, 82], //Žofie 66
# [41, 74], //Běla 65
# [53, 73], //Bohumil 65
# [57, 77], //Dobromila 65
# [47, 76], //Ferdinand 65
# [41, 78], //Hedvika 65
# [56, 74], //Jarmila 65
# [54, 72], //Jaromíra 65
# [54, 72], //Jaroslava 65
# [53, 76], //Margita 65
# [55, 73], //Oldřiška 65
# [54, 74], //Věra 65
# [51, 73], //Bedřich 64
# [53, 72], //Bohuslav 64
# [54, 73], //Lydie 64
# [49, 74], //Arnošt 63
# [47, 71], //Bořivoj 63
# [49, 73], //Emil 63
# [46, 72], //František 63
# [52, 72], //Ján 63
# [48, 71], //Květa 63
# [49, 73], //Ludvík 63
# [48, 71], //Oldřich 63
# [48, 75], //Otto 63
# [21, 73], //Anna 62
# [50, 72], //Anton 62
# [55, 68], //Dáša 62
# [56, 71], //Drahuše 62
# [47, 71], //Helena 62
# [45, 71], //Josef 62
# [52, 71], //Jozef 62
# [51, 72], //Karol 62
# [50, 71], //Miloslav 62
# [53, 69], //Miluše 62
# [45, 71], //Otakar 62
# [54, 68], //Radoslava 62
# [47, 72], //Rudolf 62
# [53, 68], //Venuše 62
# [52, 71], //Zdeňka 62
# [49, 69], //Čestmír 61
# [50, 68], //Drahomír 61
# [47, 71], //Gustav 61
# [52, 69], //Květoslav 61
# [52, 69], //Milena 61
# [48, 70], //Stanislava 61
# [47, 69], //Břetislav 60
# [45, 71], //Olga 60
# [47, 68], //Svatava 60
# [45, 69], //Svatopluk 60
# [54, 67], //Viera 60
# [46, 69], //Vladislav 60
# [46, 68], //Vlastislav 60
# [48, 67], //Zdena 60
# [48, 68], //Zdenek 60
# [35, 70], //Antonín 59
# [46, 69], //Evžen 59
# [52, 67], //Janka 59
# [49, 66], //Jindra 59
# [51, 67], //Naděžda 59
# [43, 74], //Vilma 59
# [46, 68], //Vladimír 59
# [44, 66], //Alena 58
# [47, 66], //Drahoslav 58
# [44, 70], //Imrich 58
# [43, 68], //Jaroslav 58
# [45, 70], //Juraj 58
# [42, 69], //Karel 58
# [42, 68], //Ladislav 58
# [44, 68], //Leo 58
# [46, 64], //Lubomír 58
# [49, 66], //Pavol 58

# %%
# nejmladší jména (podle medianu)
medians_sorted = sorted(name_medians, key=lambda x: name_medians[x][1], reverse=True)
for name in medians_sorted[:120]:
    if name != "NEZJIŠTĚNO":
        print("[" + str(2017-name_medians[name][2]) + ", " +str(2017-name_medians[name][0]) + "], //" + name.title(), end=" ")
        print(2017-name_medians[name][1])
# Out:
# [2, 7], //Eliáš 4
# [2, 7], //Ella 4
# [2, 7], //Mia 4
# [3, 10], //Damián 5
# [2, 9], //Emma 5
# [3, 9], //Leontýna 5
# [3, 10], //Liliana 5
# [3, 7], //Sofie 5
# [2, 8], //Stela 5
# [2, 8], //Stella 5
# [2, 11], //Teodor 5
# [3, 8], //Tobias 5
# [3, 8], //Tobiáš 5
# [3, 9], //Amálie 6
# [3, 9], //Ela 6
# [3, 9], //Elen 6
# [3, 10], //Ema 6
# [3, 13], //Izabela 6
# [3, 12], //Josefína 6
# [3, 9], //Justýna 6
# [3, 9], //Laura 6
# [3, 9], //Max 6
# [3, 12], //Maxmilián 6
# [3, 9], //Nella 6
# [3, 10], //Oliver 6
# [2, 10], //Rozálie 6
# [3, 10], //Sebastian 6
# [3, 10], //Sebastián 6
# [3, 12], //Alex 7
# [3, 12], //Ellen 7
# [3, 11], //Jáchym 7
# [4, 10], //Matyáš 7
# [4, 11], //Maxim 7
# [3, 17], //Mikuláš 7
# [4, 11], //Samuel 7
# [3, 11], //Sofia 7
# [4, 11], //Vanesa 7
# [3, 12], //Viktorie 7
# [3, 35], //Vincent 7
# [4, 13], //Agáta 8
# [4, 13], //Jonáš 8
# [4, 14], //Klaudie 8
# [5, 13], //Nela 8
# [5, 15], //Nelly 8
# [5, 14], //Nicolas 8
# [4, 13], //Šimon 8
# [4, 12], //Valentýna 8
# [5, 12], //Vanessa 8
# [4, 13], //Vítek 8
# [5, 13], //Anna Marie 9
# [4, 24], //Beáta 9
# [3, 57], //Emílie 9
# [4, 43], //Hugo 9
# [4, 15], //Kristián 9
# [4, 15], //Kryštof 9
# [6, 12], //Nicol 9
# [5, 16], //Nikolas 9
# [4, 21], //Šarlota 9
# [5, 14], //Tadeáš 9
# [5, 15], //Valérie 9
# [5, 17], //Adrian 10
# [6, 15], //Bára 10
# [5, 26], //Julie 10
# [6, 15], //Natálie 10
# [6, 24], //Prokop 10
# [4, 32], //Albert 11
# [5, 58], //Anastázie 11
# [6, 29], //Dorota 11
# [6, 21], //Johana 11
# [6, 17], //Kevin 11
# [5, 31], //Mariana 11
# [6, 17], //Matěj 11
# [6, 19], //Matouš 11
# [6, 16], //Sára 11
# [5, 32], //Valerie 11
# [5, 38], //Viola 11
# [7, 20], //Adam 12
# [7, 19], //Denis 12
# [6, 25], //Ester 12
# [7, 20], //Karolína 12
# [7, 17], //Sarah 12
# [7, 21], //Adéla 13
# [7, 27], //Simon 13
# [7, 31], //Štěpán 13
# [7, 26], //Adriana 14
# [7, 20], //Dominik 14
# [7, 30], //Eliška 14
# [6, 22], //Nikol 14
# [5, 65], //Bruno 15
# [8, 25], //Filip 15
# [10, 25], //Natalie 15
# [8, 53], //Valentina 15
# [8, 27], //Erik 16
# [5, 39], //Nina 16
# [9, 25], //Patricie 16
# [8, 29], //Vojtěch 16
# [10, 24], //Aneta 17
# [8, 36], //Magdaléna 17
# [11, 24], //Sabina 17
# [10, 26], //Tereza 17
# [5, 56], //Elena 18
# [7, 45], //Gabriel 18
# [8, 34], //Linda 18
# [6, 54], //Oskar 18
# [8, 27], //Robin 18
# [9, 27], //Jakub 19
# [11, 25], //Kristýna 19
# [14, 25], //Nicole 19
# [12, 25], //Nikola 19
# [11, 26], //Patrik 19
# [9, 43], //Terezie 19
# [10, 36], //Daniel 20
# [12, 24], //Dominika 20
# [16, 24], //Nicola 20
# [10, 40], //Anita 21
# [11, 30], //Barbora 21
# [9, 35], //Dan 21
# [11, 32], //Diana 21
# [11, 31], //Klára 22
# [7, 40], //Beata 23

# %%
# největší spread
spread = {}
for name in name_medians:
    spread[name] = int(name_medians[name][2])-int(name_medians[name][0])
spread = sorted(spread, key=lambda x: int(spread[x]),reverse=True)
for name in spread[:25]:
        print("[" + str(2017-name_medians[name][2]) + ", " +str(2017-name_medians[name][0]) + "], //" + name.title(), end=" ")
        print(2017-name_medians[name][1])
for name in spread[:25]:
    print('"' + name.title() + '", ',end="")
for name in spread[:25]:
    print(str(2017-name_medians[name][1]) + ', ',end="")
# Out:
# [9, 82], //Žofie 66
# [9, 75], //Anežka 34
# [5, 65], //Bruno 15
# [11, 67], //Alžběta 28
# [13, 68], //Hubert 52
# [3, 57], //Emílie 9
# [5, 58], //Anastázie 11
# [21, 73], //Anna 62
# [14, 66], //Vilém 45
# [5, 56], //Elena 18
# [17, 66], //Vanda 43
# [6, 54], //Oskar 18
# [18, 65], //Alexander 50
# [23, 70], //Cyril 52
# [20, 65], //Čeněk 44
# [8, 53], //Valentina 15
# [19, 63], //Magdalena 43
# [16, 58], //Andrej 38
# [6, 48], //Lea 23
# [10, 50], //Alexandr 29
# [22, 62], //Kristina 38
# [4, 43], //Hugo 9
# [7, 45], //Gabriel 18
# [17, 55], //Tamara 40
# [27, 65], //Zora 53
# "Žofie", "Anežka", "Bruno", "Alžběta", "Hubert", "Emílie", "Anastázie", "Anna", "Vilém", "Elena", "Vanda", "Oskar", "Alexander", "Cyril", "Čeněk", "Valentina", "Magdalena", "Andrej", "Lea", "Alexandr", "Kristina", "Hugo", "Gabriel", "Tamara", "Zora", 66, 34, 15, 28, 52, 9, 11, 62, 45, 18, 43, 18, 50, 52, 44, 15, 43, 38, 23, 29, 38, 9, 18, 40, 53,

# %%
# 25 nejčastějších jmen
for name, subtab in table.sort_values(by="3000",ascending=False).head(n=25).iterrows():
        #print("[" + str(2017-name_medians[name][2]) + ", " +str(2017-name_medians[name][0]) + "], //" + name.title(), end=" ")
        #print(2017-name_medians[name][1])
        print(str(2017-name_medians[name][1]) + ', ', end="")
# Out:
# 51, 37, 43, 50, 69, 62, 46, 34, 30, 58, 55, 54, 53, 62, 56, 56, 32, 63, 41, 29, 29, 19, 53, 65, 58,

# %%
# 25 nejčastějších jmen
table.sort_values(by="2016",ascending=False)["2016"].head(n=250)
# Out:
# JMÉNO
# JAKUB        2756
# JAN          2426
# ELIŠKA       2219
# ADAM         2020
# TEREZA       1915
# TOMÁŠ        1843
# ANNA         1765
# MATYÁŠ       1727
# FILIP        1607
# ONDŘEJ       1575
# VOJTĚCH      1569
# MATĚJ        1553
# DAVID        1532
# ADÉLA        1530
# LUKÁŠ        1457
# NATÁLIE      1382
# DOMINIK      1278
# EMA          1274
# VIKTORIE     1246
# SOFIE        1238
# MARTIN       1232
# DANIEL       1224
# KAROLÍNA     1187
# ŠIMON        1092
# PETR         1032
# ŠTĚPÁN       1032
# KRISTÝNA     1017
# BARBORA      1016
# VERONIKA      987
# NELA          978
#              ...
# ALEXANDER      56
# SEBASTIEN      56
# LIBOR          55
# KARLA          52
# DAMIAN         51
# ELISABETH      51
# SANDRA         50
# LEONA          50
# TINA           49
# MELANIE        49
# MEDA           49
# TAMARA         48
# TEA            48
# FRANTIŠKA      48
# VIVIEN         48
# IVANA          45
# SILVIE         45
# CHARLOTTE      45
# VÍTĚZSLAV      45
# DARINA         45
# PAVLA          44
# SARAH          44
# MATHIAS        43
# SOŇA           43
# ANDREJ         43
# VOJTA          43
# VALENTINA      43
# MAXMILIAN      42
# CHRISTIAN      42
# LUCAS          42
# Name: 2016, Length: 250, dtype: int64
